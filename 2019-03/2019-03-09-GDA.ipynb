# %% [markdown]
# # Gaussian Discriminant Analysis

# %% [markdown]
# Setting: The Gaussian Discriminant Analysis assumes that y, x|y=0 and x|y=1 are such that`

# %% [markdown]
# 1. y∼Bernoulli(ϕ)
# 2. x|y=0∼N(μ0,Σ)
# 3. x|y=1∼N(μ1,Σ)

# %% [markdown]
# Estimation: The following table sums up the estimates that we find when maximizing the likelihood:

# %% [markdown]
# ![GDA](Figure/GDA.png)

# %% [markdown]
# # Gaussian Discriminant Analysis - an example of Generative Learning Algorithms

# %% [markdown]
# Source(EN): https://towardsdatascience.com/gaussian-discriminant-analysis-an-example-of-generative-learning-algorithms-2e336ba7aa5c

# %% [markdown]
# ### Premise
# Distribution of p(x|y=k) is (Gaussian)
# Distribution of p(y) is (Bernoulli)

# %% [markdown]
# ### Aim
# In this approach we try to model p(x|y) and p(y) as oppose to p(y|x)

# %% [markdown]
# ### Explain
# Consider the same binary classification problem where we want learn to distinguish between two classes, class A (y=1) and class B (y=0) based on some features. Now we take all the examples of label A and try to learn the features and build a model for class A. Then we take all the examples labeled B and try to learn it’s features and build a separate model for class B. Finally to classify a new element, we match it against each model and see which one fits better
# (按照y值分类，每一个类别训练一个模型，新数据放入模型们中，看哪一个最适合)

# %% [markdown]
# ### Example

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# %%
plt.scatter(X[:,0],X[:,1])
plt.show()

# %%
plt.scatter(X.petal_length,X.petal_width,c=X.species)
plt.legend()
plt.title('Iris Classification')
# Out:
# Text(0.5,1,'Iris Classification')

# %%
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
clf = QuadraticDiscriminantAnalysis()

# %%
iris_x = X.iloc[:,0:2].values

# %%
iris_y = X.species.values

# %%
clf.fit(iris_x.values,iris_y)
# Out:
# QuadraticDiscriminantAnalysis(priors=None, reg_param=0.0,
#                store_covariance=False, store_covariances=None, tol=0.0001)

# %%
clf.predict([[5.1, 3.5]])
# Out:
# array([0])

# %%
clf.predict_proba([[6.0, 3.5]])
# Out:
# array([[0.01723162, 0.98276838]])
